# %%
# !pip install transformers

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-004f6d97-33e4-42cc-8835-11652b8068d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-004f6d97-33e4-42cc-8835-11652b8068d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['QG using t5 model.csv']))
df = df.drop('Unnamed: 0',axis=1)
df
# Out:
#                            keyphrase  \
# 0                  transfer learning
# 1  natural language processing (nlp)
# 2                                nlp
# 3                       text-to-text
# 4             language understanding
# 5             pretraining objectives
# 6                             corpus
# 7                      summarization
# 8                 question answering
#
#                                              context  \
# 0  ['Transfer learning, where a model is first pr...
# 1  ['Transfer learning, where a model is first pr...
# 2  ['In this paper, we explore the landscape of t...
# 3  ['In this paper, we explore the landscape of t...
# 4  ['Our systematic study compares pretraining ob...
# 5  ['Our systematic study compares pretraining ob...
# 6  ['By combining the insights from our explorati...
# 7  ['By combining the insights from our explorati...
# 8  ['By combining the insights from our explorati...
#
# ...

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
model_name = "deepset/deberta-v3-large-squad2"
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
answers = []
for (a,b) in zip(df['context'],df['question']):
  QA_input = {
    'question': b,
    'context': a}
  res = nlp(QA_input)
  model = AutoModelForQuestionAnswering.from_pretrained(model_name)
  tokenizer = AutoTokenizer.from_pretrained(model_name)
  answers.append(res['answer'])
answers
# Out:
# ["['Transfer learning,",
#  "['Transfer learning,",
#  ' future work',
#  ' introducing a unified framework',
#  ' pretraining objectives,',
#  ' pretraining objectives,',
#  ' summarization, question answering, ntext classification,',
#  ' summarization, question answering, ntext classification,',
#  ' summarization, question answering, ntext classification,']

# %% [markdown]
# <h1> Adding answers to DataFrame <h1>

# %%
df['answers'] = answers
df
# Out:
#                            keyphrase  \
# 0                  transfer learning
# 1  natural language processing (nlp)
# 2                                nlp
# 3                       text-to-text
# 4             language understanding
# 5             pretraining objectives
# 6                             corpus
# 7                      summarization
# 8                 question answering
#
#                                              context  \
# 0  ['Transfer learning, where a model is first pr...
# 1  ['Transfer learning, where a model is first pr...
# 2  ['In this paper, we explore the landscape of t...
# 3  ['In this paper, we explore the landscape of t...
# 4  ['Our systematic study compares pretraining ob...
# 5  ['Our systematic study compares pretraining ob...
# 6  ['By combining the insights from our explorati...
# 7  ['By combining the insights from our explorati...
# 8  ['By combining the insights from our explorati...
#
# ...

# %%
from google.colab import files
df.to_csv('QA using deberta.csv', encoding = 'utf-8-sig') 
files.download('QA using deberta.csv')
